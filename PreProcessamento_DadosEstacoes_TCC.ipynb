# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls /content/drive/My\ Drive
import pandas as pd

# Filtragem dos dados do Nordeste
arquivos = ['/content/drive/My Drive/ML/Kaggle/2018.csv',
    '/content/drive/My Drive/ML/Kaggle/2019.csv',
    '/content/drive/My Drive/ML/Kaggle/2020.csv',
    '/content/drive/My Drive/ML/Kaggle/2021.csv',
    '/content/drive/My Drive/ML/Kaggle/2022.csv',
    '/content/drive/My Drive/ML/Kaggle/2023.csv']
estados_nordeste = ['AL', 'BA', 'CE', 'MA', 'PB','PE', 'PI', 'RN', 'SE']
for file_path in arquivos:
    df = pd.read_csv(file_path)
    df['UF'] = df['UF'].str.strip().str.upper()
    df_nordeste = df[df['UF'].isin(estados_nordeste)]
    print(f"\nNúmero de registros da região Nordeste no arquivo {file_path}: {df_nordeste.shape[0]}")
    new_file_path = file_path.replace('.csv', '_nordeste.csv')
    df_nordeste.to_csv(new_file_path, index=False)
    print(f"Arquivo filtrado salvo em: {new_file_path}")

# lista de arquivos filtrados
arquivos_filtrados = ['/content/drive/My Drive/ML/Kaggle/2018_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2019_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2020_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2021_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2022_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2023_nordeste.csv']
dfs = []
for file_path in arquivos_filtrados:
    df = pd.read_csv(file_path)
    dfs.append(df)
# Concatenação de todos os DataFrames em um único
df_final = pd.concat(dfs, ignore_index=True)
output_file = '/content/drive/My Drive/ML/Kaggle/estacoes_18_23.csv'
df_final.to_csv(output_file, index=False)
# Out:
# <ipython-input-17-016199a2b097>:18: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Arquivo concatenado salvo em: /content/drive/My Drive/ML/Kaggle/estacoes_18_23.csv

# %%
import pandas as pd
estacoes = pd.read_csv('/content/drive/My Drive/ML/Kaggle/estacoes_18_23.csv', low_memory=False)

if not estacoes.empty:
    print("\nDimensões de Estações antes da remoção:\n{0}\n".format(estacoes.shape))

    # Listar os campos importantes para manter, incluindo estacao e estado
    campos = [
        'Data', 'LATITUDE', 'LONGITUDE', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
        'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
        'UMIDADE RELATIVA DO AR, HORARIA (%)',
        'VENTO, VELOCIDADE HORARIA (m/s)', 'VENTO, DIREÇÃO HORARIA (gr) (° (gr))',
        'ESTACAO', 'UF']
    # Remover demais campos
    estacoes_resumo = estacoes[campos]
    estacoes_resumo_csv('/content/drive/My Drive/ML/Kaggle/estacoes_resumo.csv', index=False)
    print("\nArquivo 'estacoes_resumida.csv' salvo com sucesso!")

else:
    print("O arquivo está vazio.")
# Out:
# Dimensões de Estações antes da remoção:
# (7587480, 31)
#
#
# Dimensões de Estações após a remoção:
# (7587480, 10)
#
#
# Primeiras 20 linhas das colunas importantes:
#
#           Data  LATITUDE  LONGITUDE PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0   2018-01-01      -6.0        -43                                0
# 1   2018-01-01      -6.0        -43                                0
# 2   2018-01-01      -6.0        -43                                0
# 3   2018-01-01      -6.0        -43                                0
# 4   2018-01-01      -6.0        -43                                0
# 5   2018-01-01      -6.0        -43                                0
# 6   2018-01-01      -6.0        -43                                0
# 7   2018-01-01      -6.0        -43                                0
# 8   2018-01-01      -6.0        -43                                0
# 9   2018-01-01      -6.0        -43                                0
# ...

# %%
import pandas as pd
# Filtragem dos dados do Nordeste
arquivos = ['/content/drive/My Drive/ML/Kaggle/2018.csv',
    '/content/drive/My Drive/ML/Kaggle/2019.csv',
    '/content/drive/My Drive/ML/Kaggle/2020.csv',
    '/content/drive/My Drive/ML/Kaggle/2021.csv',
    '/content/drive/My Drive/ML/Kaggle/2022.csv',
    '/content/drive/My Drive/ML/Kaggle/2023.csv']
estados_nordeste = ['AL', 'BA', 'CE', 'MA', 'PB','PE', 'PI', 'RN', 'SE']
for file_path in arquivos:
    df = pd.read_csv(file_path)
    df['UF'] = df['UF'].str.strip().str.upper()
    df_nordeste = df[df['UF'].isin(estados_nordeste)]
    print(f"\nNúmero de registros da região Nordeste no arquivo {file_path}:
    {df_nordeste.shape[0]}")
    new_file_path = file_path.replace('.csv', '_nordeste.csv')
    df_nordeste.to_csv(new_file_path, index=False)
    print(f"Arquivo filtrado salvo em: {new_file_path}")

# Concatenação dos arquivos anuais
arquivos_filtrados = ['/content/drive/My Drive/ML/Kaggle/2018_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2019_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2020_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2021_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2022_nordeste.csv',
    '/content/drive/My Drive/ML/Kaggle/2023_nordeste.csv']
dfs = []
for file_path in arquivos_filtrados:
    df = pd.read_csv(file_path)
    dfs.append(df)
df_final = pd.concat(dfs, ignore_index=True)
output_file = '/content/drive/My Drive/ML/Kaggle/estacoes_18_23.csv'
df_final.to_csv(output_file, index=False)
print(f"Arquivo concatenado salvo em: {output_file}")
# Filtragem dos campos a serem utilizados
estacoes = pd.read_csv('/content/drive/My Drive/ML/Kaggle/estacoes_18_23.csv',
                       low_memory=False)
print("\nDimensões de Estações antes da remoção:\n{0}\n".format(estacoes.shape))
campos_interessantes = ['Data', 'LATITUDE', 'LONGITUDE',
        'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
        'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
        'UMIDADE RELATIVA DO AR, HORARIA (%)','VENTO, VELOCIDADE HORARIA (m/s)',
        'VENTO, DIREÇÃO HORARIA (gr) (° (gr))','ESTACAO', 'UF']
estacoes_filtrado = estacoes[campos_interessantes]
estacoes_filtrado.to_csv(
    '/content/drive/My Drive/ML/Kaggle/estacoes_resumida.csv', index=False)
# Out:
# Dimensões de Estações antes da remoção:
# (7587480, 31)
#
#
# Dimensões de Estações após a remoção:
# (7587480, 10)
#
#
# Primeiras 20 linhas das colunas importantes:
#
#           Data  LATITUDE  LONGITUDE PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0   2018-01-01      -6.0        -43                                0
# 1   2018-01-01      -6.0        -43                                0
# 2   2018-01-01      -6.0        -43                                0
# 3   2018-01-01      -6.0        -43                                0
# 4   2018-01-01      -6.0        -43                                0
# 5   2018-01-01      -6.0        -43                                0
# 6   2018-01-01      -6.0        -43                                0
# 7   2018-01-01      -6.0        -43                                0
# 8   2018-01-01      -6.0        -43                                0
# 9   2018-01-01      -6.0        -43                                0
# ...
